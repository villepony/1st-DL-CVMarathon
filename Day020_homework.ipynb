# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# * 請附上截圖：_______
#
# ![]()

# %%
import requests
import json

r = requests.get('https://www.dcard.tw/service/api/v2/popularForums/GetPage?pageKey=d5e1b1c9-e808-469b-a5ab-74c2d8782dca')
d = json.loads(r.text)

d
# Out:
# {'pageKey': 'd5e1b1c9-e808-469b-a5ab-74c2d8782dca',
#  'nextKey': '94a2b8b1-006d-4c60-9af8-33fbb4ceaeb2',
#  'items': [{'id': '3f0027cd-fe1c-44a3-bfea-de14a291da66',
#    'name': 'BLACKPINK',
#    'alias': 'blackpink',
#    'posts': [{'id': 234637484,
#      'title': 'Lisa成為MAC全球代言人💗',
#      'excerpt': '恭喜莎莎在Celine全球大使、Bvlgari韓國品牌大使後，獲得了新的品牌代言，MAC全球代言人，化妝品牌MAC的全球品牌代言人，官方認證：臺灣的MAC官網也可以看到莎的身影囉：最近的粉墨真的太為她'}]},
#   {'id': 'c1f60d65-4f49-4a56-9c00-f162c93e31a9',
#    'name': '親子',
#    'alias': 'parentchild',
#    'posts': [{'id': 234631843,
#      'title': '最難熬的七天',
#      'excerpt': '我跟我老公最近一直努力第二胎，就在前天被他慫恿去驗孕，原本我心想應該是一條線吧！，因為當下也沒有其他明顯懷孕徵兆，只有月經特別晚來（我的經期很亂），結果驗完出現第二條淡淡的線！期待隔天早上又驗一次，線'}]},
#   {'id': '50b54456-b7d2-455c-a5b3-a883bba6f1a2',
#    'name': '塔羅',
#    'alias': 'tarot',
#    'posts': [{'id': 234639664,
#      'title': '#塔羅求解 塔羅抽到的三張牌',
#      'excerpt': '如題，我抽到了以下這三張塔羅牌，我所詢問的問題是，我該不該繼續堅持這段感情，該不該努力跟他互動 然後把心結打開，-概述，我跟交往半年多的男朋友 前陣子突然跟我提了分手，訊息上講了許多 不愛了 膩了 覺'}]},
#   {'id': '817d71bb-ebdf-4326-b8aa-10df4fcdf03a',
#    'name': '省錢',
#    'alias': 'savemoney',
#    'posts': [{'id': 234632072,
#      'title': '#其他 我買貼圖從來沒花過錢',
#      'excerpt': '我辦這隻line帳號3年多了，從來沒有花錢買過代幣買貼圖主題之類的，但是我買過的主題有10個 貼圖有26個 表情貼有3個，全部都是靠賺代幣買的，至於怎麼賺代幣的話 我想大家應該都知道，不過我還是簡單說'}]},
#   {'id': 'd43f33f9-873f-46b3-9f24-38c90056b96c',
#    'name': '考試',
#    'alias': 'exam',
#    'posts': [{'id': 234639697,
#      'title': '有關司律二試考場',
#      'excerpt': '請問今年北部考場，是勞社跟海海組在錦和高中，其他的都在國家考場嗎？還是有其他組也在錦和？另外也想問一下這次座位北部也是司律一起同間教室嗎？ 也就是最後一節科只考司法官的考生先走，是這樣嗎？謝謝大家！'}]},
#   {'id': 'cd2959fe-5515-4c1e-bd35-1cd4c36b44f0',
#    'name': '新生季',
#    'alias': 'freshman',
#    'posts': [{'id': 234639445,
#      'title': '脫北學生的心裡話-趴two',
#      'excerpt': '嗨嗨大家好阿！，回應聲量太多了，我決定發第二篇，並統一回覆一下那些問題，1.這是一篇釣魚文，既然我都決定發在新生季了當然要阿！，新生季是有幾篇有破千上熱門的？？我不敢說一千六是一個多大的數字啦！，不然'}]},
#   {'id': 'ba0145a2-adff-4229-9a84-9b26ebd2f7f0',
#    'name': '戲劇綜藝',
#    'alias': 'tvepisode',
#    'posts': [{'id': 234639544,
#      'title': '（已解）Running man 無中字版本在哪看',
#      'excerpt': '想問問大家 就是沒中字的版本的running man在哪裡看的，想要練習韓文聽力，但我找不到，如果覺得不妥在刪文，謝謝大家'}]},
#   {'id': '919f8537-6268-4404-b319-0cf46111ba34',
#    'name': '牙齒矯正',
#    'alias': 'orthodontics',
#    'posts': [{'id': 234633897,
#      'title': '#分享 傳統矯正半年',
#      'excerpt': '一直都知道自己牙齒蠻亂的，尤其是下排，但就是懶得去諮詢矯正 覺得很麻煩XD，所以拍照的時候都只會露出上排，還都只拍沒有那麼亂牙齒的的左臉，直到有一天 在啃豬肉乾的時候，把以前做過根管治療，做到一半沒戴'}]},
#   {'id': '72f262c4-75aa-4d75-ab0e-cd7bd09e69b5',
#    'name': '遊戲',
#    'alias': 'game',
#    'posts': [{'id': 234639564,
#      'title': '微軟：我們中出了一個叛徒',
#      'excerpt': '微軟說對手的好話早就不是新聞了，在社群媒體上稱讚SONY或老任，也不是什麼稀奇的事，但今天的新聞我看到快笑死，竟然直接幫PS4宣傳、賣遊戲！？在日本微軟商城的《NBA 2K21》介紹中，開頭就直接寫著'}]},
#   {'id': '16d8d779-4aff-4455-93e0-4a6cf3413d19',
#    'name': '傳說對決',
#    'alias': 'aov',
#    'posts': [{'id': 234634978,
#      'title': '這到底三小bug我快笑死',
#      'excerpt': '原來小丑和若依可以這樣搞，不知道是bug還是正常現象'}]},
#   {'id': 'c82dae3f-28ba-4aae-961d-c754e6ccd37a',
#    'name': '手作',
#    'alias': 'handicrafts',
#    'posts': [{'id': 234634208,
#      'title': '最近的袖珍黏土作品#5',
#      'excerpt': '嗨嗨～又來分享我最近的袖珍黏土作品們，這次也是從大家的點餐開始，首先是我最近最喜歡的作品，麻婆豆腐大大，只做豆腐本人太孤單，決定作成簡餐的樣子，小時候有點特別的日子就會吃簡餐，對我來說非常有意義，（豆'}]},
#   {'id': '3b54b08f-27c3-4048-9777-c40def9ac9e1',
#    'name': '隱形眼鏡',
#    'alias': 'contact_lens',
#    'posts': [{'id': 234639716,
#      'title': '高度近視戴隱眼ಠ_ಠ',
#      'excerpt': '小弟我近視800多度、散光200度，上大學後因為開始在意外表而配戴隱形眼鏡，但戴上去覺得頭有點暈、近的東西看不清楚、東西放大、臉變得奇怪，雖然一週後頭暈減輕但還是覺得不適應（~_~；），有人也是這樣嗎'}]},
#   {'id': '37a78696-f6a6-48ec-a19f-688f799a2aed',
#    'name': '靈異',
#    'alias': 'marvel',
#    'posts': [{'id': 234639714,
#      'title': '佛牌見聞錄：蘭納貓路過',
#      'excerpt': '「你知道喝酒跟喝水的分別嗎？酒，越喝越暖，水會越喝越寒。」——〈東邪西毒〉小時候喝酒是標新立異、是叛逆；長大以後的我們，喝酒是為了麻痺自己、忘卻生活，總是喝得大醉一場，隔天還得起床面對一成不變的日子，'}]},
#   {'id': 'd7db42a8-bedb-4ea2-96a7-c9034f4dd89a',
#    'name': '烹飪',
#    'alias': 'cooking',
#    'posts': [{'id': 234638419,
#      'title': '第一次成為社畜的自炊日子',
#      'excerpt': '自從開始成為社畜後，每天煩惱中午要吃什麼的情況，不減反增（跟我的體重一樣），於是在壓到胖子的最後一根薯條出現後，決定要展開自己備餐的日子⋯，但說到備餐，身為社畜的我怎麼可能有廚房呢？好家在全聯聽見我的'}]},
#   {'id': 'cbf56d6a-2fa9-4c63-b646-47b27abf1c02',
#    'name': '動物森友會',
#    'alias': 'animal_crossing',
#    'posts': [{'id': 234639623,
#      'title': '不乾淨晴天搬家ಥ_ಥ',
#      'excerpt': '第一代島民晴天要搬家了～有人要收養嗎，伴手禮隨意～無償也行 好好對待他就行了，他真的很可愛 回應也超可愛，還幫我取一堆綽號 多到其他島民都跑來問，能不能也那樣叫我 真的很可愛 收了不後悔唷～剛創島什麼'}]},
#   {'id': '58dba906-09c2-4808-9206-11c008c9ef16',
#    'name': '研究所',
#    'alias': 'graduate_school',
#    'posts': [{'id': 234638073,
#      'title': '中央推甄報名人數一覽（今年和去年比較）',
#      'excerpt': '今年的：去年的：祝大家推甄順利！找教授順利！兩年順利畢業！找到好工作賺大錢家庭幸福美滿！'}]},
#   {'id': '275e0c11-82d0-43df-9606-502f5727716d',
#    'name': '電影',
#    'alias': 'movie',
#    'posts': [{'id': 234639721,
#      'title': '刻在我心底的名字',
#      'excerpt': '最近剛剛看完刻在我心底的名字，看完之後發現曾敬華真的好帥，感覺如果他真的出現在我身邊，我一定會瘋狂的去追求他，但.......裡面同志被打的橋段我覺得蠻恐怖的，還有老爺爺狂吸男主的部分真的很不舒服，最'}]},
#   {'id': 'b22d2f5d-3c06-4d08-96b8-770eb38e8f96',
#    'name': '護理',
#    'alias': 'nursing',
#    'posts': [{'id': 234639477,
#      'title': '#單位及薪資問題 - 安南醫院',
#      'excerpt': '板上各位學長姐好，最近剛搬家到台南，想請問一下安南醫院的薪資福利，還有有沒有比較推薦的單位，目前是比較傾向於急重症單位'}]},
#   {'id': '283fe663-ed14-4f3b-b472-1fbdd7c26b00',
#    'name': '插畫',
#    'alias': 'illustration',
#    'posts': [{'id': 234639586,
#      'title': '100對👫似顏繪挑戰',
#      'excerpt': '在2020發生許多令人遺憾事情，也提醒著我們要好好的珍惜身邊的那一位，所以我想挑戰畫100對情侶或是夫妻，來倒數2020 讓這個看起來令人難過的一年，最後能夠甜蜜的劃下句點。所以如果你願意的話也喜歡我'}]},
#   {'id': '1a14ba93-3989-47e5-aedc-a3918963100e',
#    'name': '香氛',
#    'alias': 'fragrance',
#    'posts': [{'id': 234635195,
#      'title': '週年慶前的敗家👻',
#      'excerpt': '首先今天的主角是她，潘海的獸首系列-flora，雖然週年慶還沒開打，但微風信義剛好有滿3000送300，腦波一弱再加上櫃哥的超好服務態度就敗了一瓶香水，全部的戰利品，一瓶香水直接就到門檻哈哈🤣，但買兩'}]},
#   {'id': 'a255fb97-4199-4bd0-9b28-1ec2c0d2f382',
#    'name': '旅遊',
#    'alias': 'travel',
#    'posts': [{'id': 234636384,
#      'title': '捕捉野生...... 呃 有人記得他是誰嗎',
#      'excerpt': ''}]},
#   {'id': 'e600760f-46c5-40a6-96b4-4b201770464a',
#    'name': '軍旅',
#    'alias': 'military',
#    'posts': [{'id': 234640179,
#      'title': '明日10/20 金六結一營入伍',
#      'excerpt': '心情有點微妙 在享受最後的自由，但還是想發問：1. 找不太到一營的相關資料（近期） 能問問學長前輩們裡面的風氣以及涼不涼硬不硬嗎...，2.真的不建議帶電動刮鬍刀嗎？目前買了傳統刮鬍刀用 但沒帶刮鬍泡'}]},
#   {'id': '6d1f3e37-667a-4f84-951d-2efebf51d32a',
#    'name': '醫美',
#    'alias': 'facelift',
#    'posts': [{'id': 234639514,
#      'title': '#分享 跌倒天后教大家如何照顧傷口',
#      'excerpt': '不知道大家身邊有沒有那種很會跌倒的人！，對 我就是那個很會跌倒的人，舉凡是跑步機上、柏油路上、樓梯上，任何可以跌倒的地方我都不會放過^___^，為此我還去做了CT斷層掃描：），有鑑於每次跌倒都跌的超荒'}]},
#   {'id': 'f04ba238-e83a-4361-a654-2bbbb62cb37e',
#    'name': '港澳感情事',
#    'alias': 'hkmacrelationship',
#    'posts': [{'id': 234640196,
#      'title': '愛佢想有未來但真係搞唔掂longd',
#      'excerpt': '雖然我地地冇時差，但佢都唔係好得閑陪我 我地要上堂 已經少wts，食完晚餐後可能要開會 or同朋友出去玩，我明佢都要social下同埋開始佢嗰邊嘅新生活，但變相冇乜時間搵我 之前一開始講左會日日Fac'}]},
#   {'id': '6bec54a2-7dfd-46b5-8752-7781b3f91efe',
#    'name': '留學',
#    'alias': 'studyabroad',
#    'posts': [{'id': 234632088,
#      'title': '東京製菓學什麼？🌸第二學期Part1🌸',
#      'excerpt': '大家好！，久違的東京製菓學什麼又來啦，這學期已經過了一半，覺得上的內容多到可以分享一下了🤣🤣，所以先來個Part1，學期結束時會再分享第二篇٩（˃̶͈̀௰˂̶͈́）و，［註：日本分三個學期 4-7月、9-12'}]},
#   {'id': '9e4476fc-d1b4-4490-a578-fc4dc95ffc52',
#    'name': 'BTS',
#    'alias': 'bts',
#    'posts': [{'id': 234638333,
#      'title': '防彈世界觀電視劇YOUTH',
#      'excerpt': '大黑確定要搞花樣年華的電視劇《YOUTH》了🤯，演員名單，徐志焄金碩珍，盧鍾賢閔玧其，安智浩鄭號錫，徐英周金南俊，金允宇朴智旻，鄭宇振金泰亨，全真㥠田柾國，韓米抵制得很嚴重 有說不要帶本名的 有說花樣'}]},
#   {'id': '9ffbd450-4416-4023-87ef-81b38703a224',
#    'name': '港澳日常',
#    'alias': 'hkmacdaily',
#    'posts': [{'id': 234638947,
#      'title': '壓力大到爆曬瘡',
#      'excerpt': '本身自己好易受到壓力，搞到好易爆瘡，依家啲功課又唔知點咁，搞到成面都係瘡勁多傷口又勁多石頭瘡，以前睇過中醫但個個星期睇又貴喎，積積埋埋啲壓力真係想死，屋企人又唔體諒淨係鬧我呢樣戈樣，我真係好撚辛苦呀'}]},
#   {'id': '0a859162-88d8-4406-8111-71c57aae84a1',
#    'name': 'Netflix',
#    'alias': 'netflix',
#    'posts': [{'id': 234633497,
#      'title': '#有雷分享 5部Netflix亞洲電影',
#      'excerpt': '前言：這次的分享比較雜，有劇情片、愛情、懸疑、喜劇，還有兩部地雷電影。心得會多少有劇情內容，介意者慎入。然後真心希望Netflix不要再推出流水線爛片，如果時間有限，以下電影最推《盲探》️，【陽光普照 '}]},
#   {'id': 'a91cd696-aaa9-4e11-a216-e7d37f898ec7',
#    'name': '台中',
#    'alias': 'taichung',
#    'posts': [{'id': 234638963,
#      'title': '學生素質？',
#      'excerpt': '有些朝陽二宿的學生、或朝陽科大的學生，每次來二宿旁邊全家買東西，完全看不起我們店員～都一副不尊重別人的態度，我都伸手拿錢了，錢也都用丟的在桌上？身為同樣年紀的小孩為什麼這麼沒有家教！還是以為我們不愛讀'}]},
#   {'id': '49eed176-a7ad-492c-b6cf-77733ab633ef',
#    'name': '無痕生活',
#    'alias': 'ecolife',
#    'posts': [{'id': 234633409,
#      'title': '分享矽膠吸管',
#      'excerpt': '最近一直很想買能喝珍珠的杯子，但是看到大家分享大象杯的評價不太好，而且自己手邊其實有杯子，環保應該是要善加利用現有資源，不是一昧的買新的產品，猶豫很久決定買矽膠粗吸管塞到環保杯裡，因為可以折，所以不喝'}]}]}

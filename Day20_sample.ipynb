# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 觀察 API 請求資訊

# %% [markdown]
# ![](https://imgur.com/qBmCUxR.jpg)

# %% [markdown]
# ![](https://imgur.com/Xi5kYFX.jpg)

# %%
import requests
import json

r = requests.get('https://fhy.wra.gov.tw/fhy/api/ReservoirInfoApi/DryAreaGetAll')
d = json.loads(r.text)

d
# Out:
# [{'AREA_NO': 'A01',
#   'AREA_NAME': '北區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 245.0,
#     'Capacity': 8799.2424832962,
#     'CapacityRate': 44.5745674288706,
#     'Status': 5,
#     'Basin_Rain': 6.5,
#     'EffectiveCapacity': 19740.5,
#     'StationNo': '10201',
#     'StationName': '石門水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T08:00:00',
#     'NWL_MX': 86.0,
#     'Capacity': 856.8,
#     'CapacityRate': 85.50898203592814,
#     'Status': 5,
#     'Basin_Rain': 12.0,
#     'EffectiveCapacity': 1002.0,
#     'StationNo': '10204',
#     'StationName': '新山水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 170.0,
#     'Capacity': 21829.88,
#     'CapacityRate': 65.0657367252351,
#     'Status': 5,
#     'Basin_Rain': 30.9,
#     'EffectiveCapacity': 33550.5,
#     'StationNo': '10205',
#     'StationName': '翡翠水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 150.0,
#     'Capacity': 1860.79,
#     'CapacityRate': 59.12562992901582,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 3147.18,
#     'StationNo': '10405',
#     'StationName': '寶山第二水庫',
#     'BasinNo': '1300',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 85.0,
#     'Capacity': 1362.308,
#     'CapacityRate': 45.4263172987789,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 2998.94,
#     'StationNo': '10501',
#     'StationName': '永和山水庫',
#     'BasinNo': '105',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T07:00:00',
#     'NWL_MX': 61.0,
#     'Capacity': 252.3249,
#     'CapacityRate': 20.64773143675536,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 1222.0466,
#     'StationNo': '10601',
#     'StationName': '明德水庫',
#     'BasinNo': '1350',
#     'Basin': None}]},
#  {'AREA_NO': 'A02',
#   'AREA_NAME': '中區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 300.0,
#     'Capacity': 6612.68,
#     'CapacityRate': 57.74509889534123,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 11451.5,
#     'StationNo': '20101',
#     'StationName': '鯉魚潭水庫',
#     'BasinNo': '1400',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T07:00:00',
#     'NWL_MX': 1408.0,
#     'Capacity': 11124.35,
#     'CapacityRate': 59.285600085269664,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 18679.0,
#     'StationNo': '20201',
#     'StationName': '德基水庫',
#     'BasinNo': '1420',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 274.5,
#     'Capacity': 79.9,
#     'CapacityRate': 55.07685944716344,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 142.17,
#     'StationNo': '20202',
#     'StationName': '石岡壩',
#     'BasinNo': '1420',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T07:00:00',
#     'NWL_MX': 1005.0,
#     'Capacity': 1045.35,
#     'CapacityRate': 27.907032620273743,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 3745.83,
#     'StationNo': '20501',
#     'StationName': '霧社水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T07:00:00',
#     'NWL_MX': 748.48,
#     'Capacity': 11451.34,
#     'CapacityRate': 89.52661209179274,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 12791.0,
#     'StationNo': '20502',
#     'StationName': '日月潭水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 211.5,
#     'Capacity': 5079.42,
#     'CapacityRate': 99.86057243156019,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 5085.0,
#     'StationNo': '20509',
#     'StationName': '湖山水庫',
#     'BasinNo': '1510',
#     'Basin': None}]},
#  {'AREA_NO': 'A03',
#   'AREA_NAME': '南區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T07:00:00',
#     'NWL_MX': 105.0,
#     'Capacity': 2182.37,
#     'CapacityRate': 86.34637145592808,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 2527.46,
#     'StationNo': '30301',
#     'StationName': '仁義潭水庫',
#     'BasinNo': '1580',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T08:00:00',
#     'NWL_MX': 109.0,
#     'Capacity': 191.0,
#     'CapacityRate': 27.63980386447871,
#     'Status': 5,
#     'Basin_Rain': 0.7,
#     'EffectiveCapacity': 691.0324,
#     'StationNo': '30401',
#     'StationName': '白河水庫',
#     'BasinNo': '1590',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T07:00:00',
#     'NWL_MX': 58.18,
#     'Capacity': 5651.0,
#     'CapacityRate': 71.74506443217165,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 7876.5,
#     'StationNo': '30501',
#     'StationName': '烏山頭水庫',
#     'BasinNo': '1590',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 230.0,
#     'Capacity': 15548.0,
#     'CapacityRate': 30.576805836889616,
#     'Status': 5,
#     'Basin_Rain': 0.3,
#     'EffectiveCapacity': 50849.0,
#     'StationNo': '30502',
#     'StationName': '曾文水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T07:00:00',
#     'NWL_MX': 180.0,
#     'Capacity': 8814.9,
#     'CapacityRate': 97.0793273201837,
#     'Status': 5,
#     'Basin_Rain': 1.5,
#     'EffectiveCapacity': 9080.1,
#     'StationNo': '30503',
#     'StationName': '南化水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 37.0,
#     'Capacity': 1493.0,
#     'CapacityRate': 98.05982108844431,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 1509.862,
#     'StationNo': '30802',
#     'StationName': '阿公店水庫',
#     'BasinNo': '308',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2020-10-19T20:00:00',
#     'NWL_MX': 142.0,
#     'Capacity': 2144.0,
#     'CapacityRate': 81.03626637497644,
#     'Status': 5,
#     'Basin_Rain': 29.7,
#     'EffectiveCapacity': 2632.875,
#     'StationNo': '31201',
#     'StationName': '牡丹水庫',
#     'BasinNo': '312',
#     'Basin': None}]}]

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。
